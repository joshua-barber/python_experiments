# %%
# These are the standard imports for this whole dealio
import pandas as pd
import numpy as np
import trueskill

from pandas import Series, DataFrame
from trueskill import Rating, quality_1vs1, rate_1vs1

# %%
alice, bob = Rating(),Rating()

# %%
quality_1vs1(alice,bob)
# Out:
# 0.4472135954999579

# %%
skill_2015a = pd.read_csv('skill ratings 2015a.csv')

# %%
skill_2015a
# Out:
#                               Team                                    Rating  \
# 0              mosman park milkmen  trueskill.Rating(mu=25.650, sigma=3.863)
# 1                   innaloo pinguz  trueskill.Rating(mu=20.003, sigma=4.917)
# 2              gmla jurassic pucks  trueskill.Rating(mu=19.426, sigma=2.232)
# 3                  creepy crawleys  trueskill.Rating(mu=17.750, sigma=2.089)
# 4                  dianella demons  trueskill.Rating(mu=27.539, sigma=2.106)
# 5             brentwood bushchooks  trueskill.Rating(mu=40.001, sigma=4.362)
# 6             mt pleasant mounties  trueskill.Rating(mu=30.251, sigma=2.182)
# 7       shenton park speed dealers  trueskill.Rating(mu=22.646, sigma=2.161)
# 8      west leederville wobbegongs  trueskill.Rating(mu=26.873, sigma=3.605)
# 9              applecross dressers  trueskill.Rating(mu=13.974, sigma=2.585)
# 10              inglewood coldcuts  trueskill.Rating(mu=19.039, sigma=2.178)
# ...

# %%
skill_2014b = pd.read_csv('skill ratings 2014b.csv')
skill_2014b
# Out:
#     Unnamed: 0                         Team  \
# 0            0      whitfords city wristies
# 1            1              greenmount doom
# 2            2               innaloo pinguz
# 3            3          mosman park milkmen
# 4            4                 mullaloozers
# 5            5       cottesloe clam hunters
# 6            6           hillarys humpbacks
# 7            7            karrinyup bandits
# 8            8           scarbra streisands
# 9            9   shenton park speed dealers
# 10          10           inglewood coldcuts
# 11          11         karrakatta grim jobs
# 12          12                   ocean beef
# 13          13               gmla guardians
# 14          14              creepy crawleys
# 15          15                  gmla angels
# 16          16         dog swamp swamp dogs
# 17          17       south perth puckaneers
# 18          18                 willo wonkas
# 19          19          gravel road grindrs
# ...
