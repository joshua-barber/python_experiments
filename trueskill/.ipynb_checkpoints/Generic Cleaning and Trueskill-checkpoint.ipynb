# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np
import trueskill

from pandas import Series, DataFrame

from trueskill import Rating, quality_1vs1, rate_1vs1

# %% [markdown]
# # Source and Destination Files

# %%
# Place source and destination files here
# Imports first
# Write the current season here so you get the correct csvs
season = '2016a'
season_year = = ''.join(x for x in season if x.isdigit())
season_year = int(season_year)
season_ab = season[-1]
results_csv = '2016a_results.csv'
oldskill_csv = 'skill ratings 2015b.csv'

# Outputs second
winloss_csv = '2016a winloss.csv'
teams_csv = '2016a_teams.csv'
newskill_csv = 'skill ratings 2016a.csv'

# %%
results = pd.read_csv(results_csv)
results.head()
# Out:
#    ROUND                                     HOME  SCORE  SCORE.1  \
# 0      1                           GMLA Guardians      9       10
# 1      1  Stirling From the Bottom Now We're Here      9       10
# 2      1                      Bicton Banter Lords     14       15
# 3      1                   Bayswater Croquet Club     15       14
# 4      1                   Labia Menora Explorers     19        5
#
#                          AWAY   OT
# 0     Churchlands Hellraisers  NaN
# 1                     U.S.S.R  NaN
# 2                  Como Mo Co   OT
# 3  Salter Point Pint Sucklers   OT
# 4     Jason Alexander Heights  NaN

# %%
for i in range(0,len(results)):
    results['OT'][i] = results['OT'][i] == "OT"

results.head()
# Out:
# C:\Anaconda2\lib\site-packages\ipykernel\__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
#    ROUND                                     HOME  SCORE  SCORE.1  \
# 0      1                           GMLA Guardians      9       10
# 1      1  Stirling From the Bottom Now We're Here      9       10
# 2      1                      Bicton Banter Lords     14       15
# 3      1                   Bayswater Croquet Club     15       14
# 4      1                   Labia Menora Explorers     19        5
#
#                          AWAY     OT
# 0     Churchlands Hellraisers  False
# 1                     U.S.S.R  False
# 2                  Como Mo Co   True
# 3  Salter Point Pint Sucklers   True
# 4     Jason Alexander Heights  False

# %%
results['IsDraw'] = results['SCORE'] == results['SCORE.1']

for i in range(0,len(results)):
    if results['OT'][i]:
        results['IsDraw'][i] = True
        
results.head()
# Out:
# C:\Anaconda2\lib\site-packages\ipykernel\__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#    ROUND                                     HOME  SCORE  SCORE.1  \
# 0      1                           GMLA Guardians      9       10
# 1      1  Stirling From the Bottom Now We're Here      9       10
# 2      1                      Bicton Banter Lords     14       15
# 3      1                   Bayswater Croquet Club     15       14
# 4      1                   Labia Menora Explorers     19        5
#
#                          AWAY     OT IsDraw
# 0     Churchlands Hellraisers  False  False
# 1                     U.S.S.R  False  False
# 2                  Como Mo Co   True   True
# 3  Salter Point Pint Sucklers   True   True
# 4     Jason Alexander Heights  False  False

# %%
# Work out if a game was actually played, and if so who won

results['Winteam']=np.NaN
results['Lossteam']=np.NaN
results['gameplayed']=np.NaN
results = results.rename(columns = {"SCORE":"homescore","SCORE.1":"awayscore"})
for i in range(0,len(results)):
    results['gameplayed'][i] = results['homescore'][i] != 0 and results['awayscore'][i] != 0
    # If home score is greater than away score
    if results['homescore'][i]>=results['awayscore'][i]:
        results['Winteam'][i]=results['HOME'][i]
        results['Lossteam'][i]=results['AWAY'][i]
    else:
        results['Winteam'][i]=results['AWAY'][i]
        results['Lossteam'][i]=results['HOME'][i]

    
results.head()
# Out:
# C:\Anaconda2\lib\site-packages\ipykernel\__main__.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda2\lib\site-packages\ipykernel\__main__.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda2\lib\site-packages\ipykernel\__main__.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda2\lib\site-packages\ipykernel\__main__.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda2\lib\site-packages\ipykernel\__main__.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#    ROUND                                     HOME  homescore  awayscore  \
# 0      1                           GMLA Guardians          9         10
# 1      1  Stirling From the Bottom Now We're Here          9         10
# 2      1                      Bicton Banter Lords         14         15
# 3      1                   Bayswater Croquet Club         15         14
# 4      1                   Labia Menora Explorers         19          5
#
#                          AWAY     OT IsDraw                  Winteam  \
# 0     Churchlands Hellraisers  False  False  Churchlands Hellraisers
# 1                     U.S.S.R  False  False                  U.S.S.R
# 2                  Como Mo Co   True   True               Como Mo Co
# 3  Salter Point Pint Sucklers   True   True   Bayswater Croquet Club
# 4     Jason Alexander Heights  False  False   Labia Menora Explorers
#
#                                   Lossteam  gameplayed
# 0                           GMLA Guardians           1
# 1  Stirling From the Bottom Now We're Here           1
# 2                      Bicton Banter Lords           1
# 3               Salter Point Pint Sucklers           1
# 4                  Jason Alexander Heights           1

# %%
results = results.drop(results.columns[[0,1,2,3,4,5]],axis=1)
winloss = results[results["gameplayed"] == 1]

# %%
x = Series(winloss['Winteam'].unique())
y = Series(winloss['Lossteam'].unique())
x=x.append(y)
x=Series(x.unique())
x=x.dropna()
x.sort_values()
# Out:
# 19                      50 Shades of Graylands
# 7                             Balcatta Bandits
# 71                           Balingup Bruisers
# 65                        Bayslaughter House 5
# 42                        Bayswater Barracudas
# 3                       Bayswater Croquet Club
# 16                          Bedford Rave Lords
# 76                         Bicton Banter Lords
# 100                      Bicton Four 'n Twenty
# 37                    Black Wall Reach Arounds
# 89                               Booragoonbagz
# 97                              Burswood 6100s
# 24                       Canning Bridge Trolls
# 0                      Churchlands Hellraisers
# 26                            City Beach Kooks
# 23                    Claremont Cereal Killahs
# 25                              Como At Me Bro
# 2                                   Como Mo Co
# 62                          Dalkeith Dalqueefs
# 74                            Dalkeith Urban's
# 53                             Dianella Demons
# 54                        Dog Swamp Swamp Dogs
# 17                     Doubleview Double Yewws
# 102                       East Freo Bae Blades
# 92          Fremantle Metropolis Double Blacks
# 43                     Freo Dirty Dog Beachers
# 5                                  GMLA Angels
# 60                              GMLA Guardians
# 93                         GMLA Jurassic Pucks
# 78                                 Get Bentley
#                         ...
# 46                   Rottnest Holy Quokkamoles
# 70                  Salter Point Pint Sucklers
# 48                            Scarbara Kadabra
# 87                       Scarborough Scar Bros
# 67                          Shannon Nollamaras
# 15                   South Perth Major Blazers
# 99        South Perth Sam's Green Eggs and Ham
# 40                          South Perth Shakas
# 90                         St James Addictions
# 69                            Stirling Archers
# 104    Stirling From The Bottom Now We're Here
# 63     Stirling From the Bottom Now We're Here
# 47                           Stoneville Sloths
# 84                           Subiaco Silkworms
# 22                           Swan View Draught
# 55                          Swanbourne Nudists
# 56                      Swanbourne Sand People
# 11                     The Swanbourne Identity
# 1                                      U.S.S.R
# 105                         Vic Park Vanguards
# 13                   Wembley Blue Light Discos
# 96                         Wembley Food Courts
# 50                West Stirling Banjo Breakers
# 72                     Westeros Perth R'hllors
# 83                Whitfords City Turbo Tuggers
# 80                            Wilson Castaways
# 45                       Yokine Drugs n' Crime
# 12                       Yokine Reservoir Dogs
# 85           You Used To Como On My Cell Phone
# 68           You Used to Como on my Cell Phone
# dtype: object

# %%
#winloss.head()

# %%
x=Series(x.unique())
x=x.sort_values()
#teams_lower = Series([])
#x = Series(winloss['Winteam'].unique())
#y = Series(winloss['Lossteam'].unique())
#x=x.append(y)
#x=Series(x.unique())

#teams = x.sort_values()
for i in range(0,len(x)):
    x[i]=x[i].lower()
teams = x

# %%
teams.unique()
# Out:
# array(['50 shades of graylands', 'balcatta bandits', 'balingup bruisers',
#        'bayslaughter house 5', 'bayswater barracudas',
#        'bayswater croquet club', 'bedford rave lords',
#        'bicton banter lords', "bicton four 'n twenty",
#        'black wall reach arounds', 'booragoonbagz', 'burswood 6100s',
#        'canning bridge trolls', 'churchlands hellraisers',
#        'city beach kooks', 'claremont cereal killahs', 'como at me bro',
#        'como mo co', 'dalkeith dalqueefs', "dalkeith urban's",
#        'dianella demons', 'dog swamp swamp dogs',
#        'doubleview double yewws', 'east freo bae blades',
#        'fremantle metropolis double blacks', 'freo dirty dog beachers',
#        'gmla angels', 'gmla guardians', 'gmla jurassic pucks',
#        'get bentley', 'greenmount doom', 'heathcote hangers', 'high gates',
#        'hillarys humpbacks',
#        'how much wood would a parkwood park if a parkwood could park wood',
#        'hungry spot heroes', 'hyde park hacks', 'inglewood coldcuts',
#        'innaloominati', 'jason alexander heights', 'k-town cooks',
#        'kalamunda hillbillies', 'karrakatta grim jobs',
#        'kensington kermits', 'labia menora explorers', 'lake mongrels',
#        'leeming chin', 'manning manchilds', 'marmion mighty drunks',
#        'maylands muthapuckas', 'mindarie molotovs', 'morley puck troopers',
#        'morning brentwood', 'mosman mooseknuckles', "mount hawt'n'horny",
#        'mount lawless', 'mt pleasant mounties', 'mullaloozers',
#        'murray street tramps', 'm\xf6rley cr\xfce', 'nedlands flanders',
#        'north beach bearded clams', 'north perth bald beavers',
#        "northbridge mdm8's", 'ocean beef', 'palmyra puck patrol',
#        'patrick bateman', 'perth city puck pirates', 'perth glory holes',
#        'riverton regretzkys', 'rocko rodents', "rocko's modern rollers",
#        'roleystone henges', 'rollerburger leedervillains',
#        'rottnest holy quokkamoles', 'salter point pint sucklers',
#        'scarbara kadabra', 'scarborough scar bros', 'shannon nollamaras',
#        'south perth major blazers', "south perth sam's green eggs and ham",
#        'south perth shakas', 'st james addictions', 'stirling archers',
#        "stirling from the bottom now we're here", 'stoneville sloths',
#        'subiaco silkworms', 'swan view draught', 'swanbourne nudists',
#        'swanbourne sand people', 'the swanbourne identity', 'u.s.s.r',
#        'vic park vanguards', 'wembley blue light discos',
#        'wembley food courts', 'west stirling banjo breakers',
#        "westeros perth r'hllors", 'whitfords city turbo tuggers',
#        'wilson castaways', "yokine drugs n' crime",
#        'yokine reservoir dogs', 'you used to como on my cell phone'], dtype=object)

# %%
# Write to CSV, manually apply lower() to the winteam and lossteam
winloss.to_csv(winloss_csv)
teams.to_csv(teams_csv)

# %%
#teams_lower = pd.read_csv(teams_csv)
#teams = teams_lower['team']

# Reread the manually fixed stuff
winloss = pd.read_csv(winloss_csv)

# %%
winloss = winloss.dropna()
for i in range(0,len(winloss)):
    winloss['Winteam'][i] = winloss['Winteam'][i].lower()
    winloss['Lossteam'][i] = winloss['Lossteam'][i].lower()
    
winloss.head()
# Out:
# C:\Anaconda2\lib\site-packages\ipykernel\__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# C:\Anaconda2\lib\site-packages\ipykernel\__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#    Unnamed: 0 IsDraw                  Winteam  \
# 0           0  False  churchlands hellraisers
# 1           1  False                  u.s.s.r
# 2           2   True               como mo co
# 3           3   True   bayswater croquet club
# 4           4  False   labia menora explorers
#
#                                   Lossteam  gameplayed
# 0                           gmla guardians           1
# 1  stirling from the bottom now we're here           1
# 2                      bicton banter lords           1
# 3               salter point pint sucklers           1
# 4                  jason alexander heights           1

# %%
#winteams = Series(winloss['Winteam'].unique())
#lossteams = Series(winloss['Lossteam'].unique())
#teams = winteams
#teams = teams.append(lossteams)
teams = Series(teams.unique())
print(teams);
print len(teams), "teams";
# Out:
# 0                       50 shades of graylands
# 1                             balcatta bandits
# 2                            balingup bruisers
# 3                         bayslaughter house 5
# 4                         bayswater barracudas
# 5                       bayswater croquet club
# 6                           bedford rave lords
# 7                          bicton banter lords
# 8                        bicton four 'n twenty
# 9                     black wall reach arounds
# 10                               booragoonbagz
# 11                              burswood 6100s
# 12                       canning bridge trolls
# 13                     churchlands hellraisers
# 14                            city beach kooks
# 15                    claremont cereal killahs
# 16                              como at me bro
# 17                                  como mo co
# 18                          dalkeith dalqueefs
# 19                            dalkeith urban's
# 20                             dianella demons
# 21                        dog swamp swamp dogs
# 22                     doubleview double yewws
# 23                        east freo bae blades
# 24          fremantle metropolis double blacks
# 25                     freo dirty dog beachers
# 26                                 gmla angels
# 27                              gmla guardians
# 28                         gmla jurassic pucks
# 29                                 get bentley
#                         ...
# 72                           roleystone henges
# 73                 rollerburger leedervillains
# 74                   rottnest holy quokkamoles
# 75                  salter point pint sucklers
# 76                            scarbara kadabra
# 77                       scarborough scar bros
# 78                          shannon nollamaras
# 79                   south perth major blazers
# 80        south perth sam's green eggs and ham
# 81                          south perth shakas
# 82                         st james addictions
# 83                            stirling archers
# 84     stirling from the bottom now we're here
# 85                           stoneville sloths
# 86                           subiaco silkworms
# 87                           swan view draught
# 88                          swanbourne nudists
# 89                      swanbourne sand people
# 90                     the swanbourne identity
# 91                                     u.s.s.r
# 92                          vic park vanguards
# 93                   wembley blue light discos
# 94                         wembley food courts
# 95                west stirling banjo breakers
# 96                     westeros perth r'hllors
# 97                whitfords city turbo tuggers
# 98                            wilson castaways
# 99                       yokine drugs n' crime
# 100                      yokine reservoir dogs
# 101          you used to como on my cell phone
# dtype: object
# 102 teams

# %% [markdown]
# # Create skill from lower(teams), update skill

# %%
skill = {name:Rating() for name in teams}
skill
# Out:
# {'50 shades of graylands': trueskill.Rating(mu=25.000, sigma=8.333),
#  'balcatta bandits': trueskill.Rating(mu=25.000, sigma=8.333),
#  'balingup bruisers': trueskill.Rating(mu=25.000, sigma=8.333),
#  'bayslaughter house 5': trueskill.Rating(mu=25.000, sigma=8.333),
#  'bayswater barracudas': trueskill.Rating(mu=25.000, sigma=8.333),
#  'bayswater croquet club': trueskill.Rating(mu=25.000, sigma=8.333),
#  'bedford rave lords': trueskill.Rating(mu=25.000, sigma=8.333),
#  'bicton banter lords': trueskill.Rating(mu=25.000, sigma=8.333),
#  "bicton four 'n twenty": trueskill.Rating(mu=25.000, sigma=8.333),
#  'black wall reach arounds': trueskill.Rating(mu=25.000, sigma=8.333),
#  'booragoonbagz': trueskill.Rating(mu=25.000, sigma=8.333),
#  'burswood 6100s': trueskill.Rating(mu=25.000, sigma=8.333),
#  'canning bridge trolls': trueskill.Rating(mu=25.000, sigma=8.333),
#  'churchlands hellraisers': trueskill.Rating(mu=25.000, sigma=8.333),
#  'city beach kooks': trueskill.Rating(mu=25.000, sigma=8.333),
#  'claremont cereal killahs': trueskill.Rating(mu=25.000, sigma=8.333),
#  'como at me bro': trueskill.Rating(mu=25.000, sigma=8.333),
#  'como mo co': trueskill.Rating(mu=25.000, sigma=8.333),
#  'dalkeith dalqueefs': trueskill.Rating(mu=25.000, sigma=8.333),
#  "dalkeith urban's": trueskill.Rating(mu=25.000, sigma=8.333),
#  'dianella demons': trueskill.Rating(mu=25.000, sigma=8.333),
#  'dog swamp swamp dogs': trueskill.Rating(mu=25.000, sigma=8.333),
#  'doubleview double yewws': trueskill.Rating(mu=25.000, sigma=8.333),
#  'east freo bae blades': trueskill.Rating(mu=25.000, sigma=8.333),
#  'fremantle metropolis double blacks': trueskill.Rating(mu=25.000, sigma=8.333),
#  'freo dirty dog beachers': trueskill.Rating(mu=25.000, sigma=8.333),
#  'get bentley': trueskill.Rating(mu=25.000, sigma=8.333),
#  'gmla angels': trueskill.Rating(mu=25.000, sigma=8.333),
#  'gmla guardians': trueskill.Rating(mu=25.000, sigma=8.333),
#  'gmla jurassic pucks': trueskill.Rating(mu=25.000, sigma=8.333),
#  'greenmount doom': trueskill.Rating(mu=25.000, sigma=8.333),
#  'heathcote hangers': trueskill.Rating(mu=25.000, sigma=8.333),
#  'high gates': trueskill.Rating(mu=25.000, sigma=8.333),
#  'hillarys humpbacks': trueskill.Rating(mu=25.000, sigma=8.333),
#  'how much wood would a parkwood park if a parkwood could park wood': trueskill.Rating(mu=25.000, sigma=8.333),
#  'hungry spot heroes': trueskill.Rating(mu=25.000, sigma=8.333),
#  'hyde park hacks': trueskill.Rating(mu=25.000, sigma=8.333),
#  'inglewood coldcuts': trueskill.Rating(mu=25.000, sigma=8.333),
#  'innaloominati': trueskill.Rating(mu=25.000, sigma=8.333),
#  'jason alexander heights': trueskill.Rating(mu=25.000, sigma=8.333),
#  'k-town cooks': trueskill.Rating(mu=25.000, sigma=8.333),
#  'kalamunda hillbillies': trueskill.Rating(mu=25.000, sigma=8.333),
#  'karrakatta grim jobs': trueskill.Rating(mu=25.000, sigma=8.333),
#  'kensington kermits': trueskill.Rating(mu=25.000, sigma=8.333),
#  'labia menora explorers': trueskill.Rating(mu=25.000, sigma=8.333),
#  'lake mongrels': trueskill.Rating(mu=25.000, sigma=8.333),
#  'leeming chin': trueskill.Rating(mu=25.000, sigma=8.333),
#  'manning manchilds': trueskill.Rating(mu=25.000, sigma=8.333),
#  'marmion mighty drunks': trueskill.Rating(mu=25.000, sigma=8.333),
#  'maylands muthapuckas': trueskill.Rating(mu=25.000, sigma=8.333),
#  'mindarie molotovs': trueskill.Rating(mu=25.000, sigma=8.333),
#  'morley puck troopers': trueskill.Rating(mu=25.000, sigma=8.333),
#  'morning brentwood': trueskill.Rating(mu=25.000, sigma=8.333),
#  'mosman mooseknuckles': trueskill.Rating(mu=25.000, sigma=8.333),
#  "mount hawt'n'horny": trueskill.Rating(mu=25.000, sigma=8.333),
#  'mount lawless': trueskill.Rating(mu=25.000, sigma=8.333),
#  'mt pleasant mounties': trueskill.Rating(mu=25.000, sigma=8.333),
#  'mullaloozers': trueskill.Rating(mu=25.000, sigma=8.333),
#  'murray street tramps': trueskill.Rating(mu=25.000, sigma=8.333),
#  'm\xf6rley cr\xfce': trueskill.Rating(mu=25.000, sigma=8.333),
#  'nedlands flanders': trueskill.Rating(mu=25.000, sigma=8.333),
#  'north beach bearded clams': trueskill.Rating(mu=25.000, sigma=8.333),
#  'north perth bald beavers': trueskill.Rating(mu=25.000, sigma=8.333),
#  "northbridge mdm8's": trueskill.Rating(mu=25.000, sigma=8.333),
#  'ocean beef': trueskill.Rating(mu=25.000, sigma=8.333),
#  'palmyra puck patrol': trueskill.Rating(mu=25.000, sigma=8.333),
#  'patrick bateman': trueskill.Rating(mu=25.000, sigma=8.333),
#  'perth city puck pirates': trueskill.Rating(mu=25.000, sigma=8.333),
#  'perth glory holes': trueskill.Rating(mu=25.000, sigma=8.333),
#  'riverton regretzkys': trueskill.Rating(mu=25.000, sigma=8.333),
#  'rocko rodents': trueskill.Rating(mu=25.000, sigma=8.333),
#  "rocko's modern rollers": trueskill.Rating(mu=25.000, sigma=8.333),
#  'roleystone henges': trueskill.Rating(mu=25.000, sigma=8.333),
#  'rollerburger leedervillains': trueskill.Rating(mu=25.000, sigma=8.333),
#  'rottnest holy quokkamoles': trueskill.Rating(mu=25.000, sigma=8.333),
#  'salter point pint sucklers': trueskill.Rating(mu=25.000, sigma=8.333),
#  'scarbara kadabra': trueskill.Rating(mu=25.000, sigma=8.333),
#  'scarborough scar bros': trueskill.Rating(mu=25.000, sigma=8.333),
#  'shannon nollamaras': trueskill.Rating(mu=25.000, sigma=8.333),
#  'south perth major blazers': trueskill.Rating(mu=25.000, sigma=8.333),
#  "south perth sam's green eggs and ham": trueskill.Rating(mu=25.000, sigma=8.333),
#  'south perth shakas': trueskill.Rating(mu=25.000, sigma=8.333),
#  'st james addictions': trueskill.Rating(mu=25.000, sigma=8.333),
#  'stirling archers': trueskill.Rating(mu=25.000, sigma=8.333),
#  "stirling from the bottom now we're here": trueskill.Rating(mu=25.000, sigma=8.333),
#  'stoneville sloths': trueskill.Rating(mu=25.000, sigma=8.333),
#  'subiaco silkworms': trueskill.Rating(mu=25.000, sigma=8.333),
#  'swan view draught': trueskill.Rating(mu=25.000, sigma=8.333),
#  'swanbourne nudists': trueskill.Rating(mu=25.000, sigma=8.333),
#  'swanbourne sand people': trueskill.Rating(mu=25.000, sigma=8.333),
#  'the swanbourne identity': trueskill.Rating(mu=25.000, sigma=8.333),
#  'u.s.s.r': trueskill.Rating(mu=25.000, sigma=8.333),
#  'vic park vanguards': trueskill.Rating(mu=25.000, sigma=8.333),
#  'wembley blue light discos': trueskill.Rating(mu=25.000, sigma=8.333),
#  'wembley food courts': trueskill.Rating(mu=25.000, sigma=8.333),
#  'west stirling banjo breakers': trueskill.Rating(mu=25.000, sigma=8.333),
#  "westeros perth r'hllors": trueskill.Rating(mu=25.000, sigma=8.333),
#  'whitfords city turbo tuggers': trueskill.Rating(mu=25.000, sigma=8.333),
#  'wilson castaways': trueskill.Rating(mu=25.000, sigma=8.333),
#  "yokine drugs n' crime": trueskill.Rating(mu=25.000, sigma=8.333),
#  'yokine reservoir dogs': trueskill.Rating(mu=25.000, sigma=8.333),
#  'you used to como on my cell phone': trueskill.Rating(mu=25.000, sigma=8.333)}

# %%
# Read in the old ratings from csv, make sure they're init'd as Rating() objects
ratings_past = pd.read_csv(oldskill_csv)
for i in range(0,len(ratings_past)):
               ratings_past['Rating'][i] = Rating(mu=ratings_past['mu'][i],)
                                                  #sigma=ratings_past['sigma'][i]#)
                                                    # This is commented out because we want to try starting from default sigma values
                                                    # Because new teams enter the mix, we are not as certain of each team's skill
ratings_past.head()
# Out:
# C:\Anaconda2\lib\site-packages\ipykernel\__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#    Unnamed: 0                       Team  \
# 0           0         perth glory-holerz
# 1           1             innaloo pinguz
# 2           2  south perth major blazers
# 3           3        gmla jurassic pucks
# 4           4               mullaloozers
#
#                                      Rating         mu     sigma
# 0  trueskill.Rating(mu=18.270, sigma=8.333)  18.269517  8.333333
# 1  trueskill.Rating(mu=20.003, sigma=8.333)  20.002770  8.333333
# 2  trueskill.Rating(mu=22.730, sigma=8.333)  22.729702  2.892885
# 3  trueskill.Rating(mu=17.670, sigma=8.333)  17.670301  2.888607
# 4  trueskill.Rating(mu=28.429, sigma=8.333)  28.428577  3.086245

# %%
# Get the old ratings (last season), send them to a new dictionary
oldratings=ratings_past.set_index('Team')['Rating'].to_dict()
oldratings;

# %%
# Get the old ratings and the ratings for the new teams
# Merge the two
mergedratings = skill.copy()
mergedratings.update(oldratings)
mergedratings
# Out:
# {'50 shades of graylands': trueskill.Rating(mu=23.540, sigma=8.333),
#  'applecross dressers': trueskill.Rating(mu=14.521, sigma=8.333),
#  'attafail whales': trueskill.Rating(mu=10.840, sigma=8.333),
#  'balcatta bandits': trueskill.Rating(mu=49.509, sigma=8.333),
#  'balingup bruisers': trueskill.Rating(mu=25.000, sigma=8.333),
#  'bayslaughter house 5': trueskill.Rating(mu=25.000, sigma=8.333),
#  'bayswater barracudas': trueskill.Rating(mu=25.000, sigma=8.333),
#  'bayswater croquet club': trueskill.Rating(mu=25.000, sigma=8.333),
#  'bedford rave lords': trueskill.Rating(mu=25.000, sigma=8.333),
#  'bicton banter lords': trueskill.Rating(mu=36.987, sigma=8.333),
#  'bicton bath salts': trueskill.Rating(mu=18.808, sigma=8.333),
#  "bicton four 'n twenty": trueskill.Rating(mu=25.000, sigma=8.333),
#  "bicton four'n twenty": trueskill.Rating(mu=20.953, sigma=8.333),
#  'black wall reach arounds': trueskill.Rating(mu=30.686, sigma=8.333),
#  'booragoonbags': trueskill.Rating(mu=18.411, sigma=8.333),
#  'booragoonbagz': trueskill.Rating(mu=15.824, sigma=8.333),
#  'brentwood bushchooks': trueskill.Rating(mu=40.001, sigma=8.333),
#  'bull creek buttchuggers': trueskill.Rating(mu=19.712, sigma=8.333),
#  'burswood 6100s': trueskill.Rating(mu=25.000, sigma=8.333),
#  'canning bridge trolls': trueskill.Rating(mu=25.000, sigma=8.333),
#  'chick park': trueskill.Rating(mu=20.301, sigma=8.333),
#  'churchlands hellraisers': trueskill.Rating(mu=38.147, sigma=8.333),
#  'city beach groins': trueskill.Rating(mu=25.922, sigma=8.333),
#  'city beach kooks': trueskill.Rating(mu=17.531, sigma=8.333),
#  'claremont cereal killahs': trueskill.Rating(mu=26.185, sigma=8.333),
#  'como at me bro': trueskill.Rating(mu=15.950, sigma=8.333),
#  'como mo co': trueskill.Rating(mu=40.070, sigma=8.333),
#  'cottesloe clam hunters': trueskill.Rating(mu=32.010, sigma=8.333),
#  'cottesloe cowards': trueskill.Rating(mu=29.174, sigma=8.333),
#  "cottesloe's hottest hoes": trueskill.Rating(mu=17.175, sigma=8.333),
#  'cotteslowbros': trueskill.Rating(mu=24.826, sigma=8.333),
#  'creepy crawleys': trueskill.Rating(mu=23.973, sigma=8.333),
#  'daglish dhe moisties': trueskill.Rating(mu=35.961, sigma=8.333),
#  'dalkeith dalqueefs': trueskill.Rating(mu=26.553, sigma=8.333),
#  "dalkeith urban's": trueskill.Rating(mu=25.000, sigma=8.333),
#  'dianella demons': trueskill.Rating(mu=29.472, sigma=8.333),
#  'dog swamp swamp dogs': trueskill.Rating(mu=22.682, sigma=8.333),
#  'doubleview double yewws': trueskill.Rating(mu=26.625, sigma=8.333),
#  'east freo bae blades': trueskill.Rating(mu=12.474, sigma=8.333),
#  'floreat flamingos': trueskill.Rating(mu=20.390, sigma=8.333),
#  'fremantle cappuccino strippers': trueskill.Rating(mu=21.304, sigma=8.333),
#  'fremantle metropolis double blacks': trueskill.Rating(mu=25.000, sigma=8.333),
#  'freo dirty dog beachers': trueskill.Rating(mu=25.000, sigma=8.333),
#  'freo fussy puckers': trueskill.Rating(mu=24.970, sigma=8.333),
#  'get bentley': trueskill.Rating(mu=11.999, sigma=8.333),
#  'gmla angels': trueskill.Rating(mu=23.058, sigma=8.333),
#  'gmla guardians': trueskill.Rating(mu=37.378, sigma=8.333),
#  'gmla jurassic pucks': trueskill.Rating(mu=17.670, sigma=8.333),
#  'gravel road grindrs': trueskill.Rating(mu=18.198, sigma=8.333),
#  'greenmount doom': trueskill.Rating(mu=27.441, sigma=8.333),
#  'heathcote hangers': trueskill.Rating(mu=30.577, sigma=8.333),
#  'high gates': trueskill.Rating(mu=25.000, sigma=8.333),
#  'highgate hommus-sexuals': trueskill.Rating(mu=30.703, sigma=8.333),
#  'hillarys humpbacks': trueskill.Rating(mu=27.376, sigma=8.333),
#  'how much wood would a parkwood park if a parkwood could park wood': trueskill.Rating(mu=26.666, sigma=8.333),
#  'hungry spot heroes': trueskill.Rating(mu=21.792, sigma=8.333),
#  'hyde park hacks': trueskill.Rating(mu=25.000, sigma=8.333),
#  'hydepark hacks': trueskill.Rating(mu=26.497, sigma=8.333),
#  'inglewood coldcuts': trueskill.Rating(mu=22.041, sigma=8.333),
#  'innaloo pinguz': trueskill.Rating(mu=20.003, sigma=8.333),
#  'innaloominati': trueskill.Rating(mu=24.088, sigma=8.333),
#  'jason alexander heights': trueskill.Rating(mu=25.000, sigma=8.333),
#  'k-town cooks': trueskill.Rating(mu=30.770, sigma=8.333),
#  'kalamunda hillbillies': trueskill.Rating(mu=25.000, sigma=8.333),
#  'karrakatta grim jobs': trueskill.Rating(mu=35.035, sigma=8.333),
#  'karrinyup bandits': trueskill.Rating(mu=29.301, sigma=8.333),
#  'kensington kermits': trueskill.Rating(mu=34.444, sigma=8.333),
#  'labia menora explorers': trueskill.Rating(mu=25.000, sigma=8.333),
#  'lake mongrels': trueskill.Rating(mu=25.779, sigma=8.333),
#  'leederphiles rolferhockey': trueskill.Rating(mu=23.550, sigma=8.333),
#  'leeming chin': trueskill.Rating(mu=25.000, sigma=8.333),
#  'manning manchilds': trueskill.Rating(mu=21.616, sigma=8.333),
#  'marmion mighty drunks': trueskill.Rating(mu=25.000, sigma=8.333),
#  'maylands muthapuckas': trueskill.Rating(mu=34.106, sigma=8.333),
#  'melville massiv': trueskill.Rating(mu=36.184, sigma=8.333),
#  'mindarie molotovs': trueskill.Rating(mu=40.456, sigma=8.333),
#  'morley puck troopers': trueskill.Rating(mu=35.644, sigma=8.333),
#  'morning brentwood': trueskill.Rating(mu=35.997, sigma=8.333),
#  'mosman mooseknuckles': trueskill.Rating(mu=35.583, sigma=8.333),
#  'mosman park milkmen': trueskill.Rating(mu=25.650, sigma=8.333),
#  'mosmanonymous': trueskill.Rating(mu=9.797, sigma=8.333),
#  "mount hawt'n'horny": trueskill.Rating(mu=25.000, sigma=8.333),
#  'mount lawless': trueskill.Rating(mu=37.967, sigma=8.333),
#  'mt lawley chai lattes': trueskill.Rating(mu=17.498, sigma=8.333),
#  'mt pleasant mounties': trueskill.Rating(mu=36.118, sigma=8.333),
#  'mullaloozers': trueskill.Rating(mu=28.429, sigma=8.333),
#  'murray street tramps': trueskill.Rating(mu=20.614, sigma=8.333),
#  'm\xf6rley cr\xfce': trueskill.Rating(mu=25.000, sigma=8.333),
#  'nedlands flanders': trueskill.Rating(mu=25.000, sigma=8.333),
#  'nedlands yung puccbois': trueskill.Rating(mu=23.282, sigma=8.333),
#  'north beach bearded clams': trueskill.Rating(mu=25.000, sigma=8.333),
#  'north perth bald beavers': trueskill.Rating(mu=22.491, sigma=8.333),
#  "northbridge mdm8's": trueskill.Rating(mu=25.000, sigma=8.333),
#  'ocean beef': trueskill.Rating(mu=38.700, sigma=8.333),
#  'palmyra puck patrol': trueskill.Rating(mu=25.000, sigma=8.333),
#  'parkwood benders': trueskill.Rating(mu=25.659, sigma=8.333),
#  'patrick bateman': trueskill.Rating(mu=25.000, sigma=8.333),
#  'perth city puck pirates': trueskill.Rating(mu=22.023, sigma=8.333),
#  'perth glory holes': trueskill.Rating(mu=25.000, sigma=8.333),
#  'perth glory holez': trueskill.Rating(mu=18.450, sigma=8.333),
#  'perth glory-holerz': trueskill.Rating(mu=18.270, sigma=8.333),
#  'perth on heat': trueskill.Rating(mu=24.034, sigma=8.333),
#  'riverton regretzkys': trueskill.Rating(mu=25.000, sigma=8.333),
#  'rocko rodents': trueskill.Rating(mu=14.245, sigma=8.333),
#  "rocko's modern rollers": trueskill.Rating(mu=25.000, sigma=8.333),
#  'roleystone henges': trueskill.Rating(mu=25.000, sigma=8.333),
#  'rollerburger leedervillains': trueskill.Rating(mu=25.000, sigma=8.333),
#  'rosemount rinsers': trueskill.Rating(mu=30.518, sigma=8.333),
#  'rottnest holy quokkamoles': trueskill.Rating(mu=25.000, sigma=8.333),
#  'salter point pint sucklers': trueskill.Rating(mu=25.000, sigma=8.333),
#  'salter point shooters': trueskill.Rating(mu=23.893, sigma=8.333),
#  'scarbara kadabra': trueskill.Rating(mu=25.000, sigma=8.333),
#  'scarborough scar bros': trueskill.Rating(mu=23.115, sigma=8.333),
#  'scarbra streisands': trueskill.Rating(mu=28.807, sigma=8.333),
#  'shannon nollamaras': trueskill.Rating(mu=25.000, sigma=8.333),
#  'shenton park speed dealers': trueskill.Rating(mu=19.682, sigma=8.333),
#  'south perth major blazers': trueskill.Rating(mu=22.730, sigma=8.333),
#  'south perth puckaneers': trueskill.Rating(mu=18.991, sigma=8.333),
#  "south perth sam's green eggs and ham": trueskill.Rating(mu=25.000, sigma=8.333),
#  'south perth shakas': trueskill.Rating(mu=22.024, sigma=8.333),
#  'st james addictions': trueskill.Rating(mu=25.687, sigma=8.333),
#  'stirling archers': trueskill.Rating(mu=25.000, sigma=8.333),
#  "stirling from the bottom now we're here": trueskill.Rating(mu=7.678, sigma=8.333),
#  'stoneville sloths': trueskill.Rating(mu=25.000, sigma=8.333),
#  'subiaco silkworms': trueskill.Rating(mu=24.051, sigma=8.333),
#  'swan view draught': trueskill.Rating(mu=25.000, sigma=8.333),
#  'swan view sharks': trueskill.Rating(mu=22.457, sigma=8.333),
#  'swanbourne nudists': trueskill.Rating(mu=22.795, sigma=8.333),
#  'swanbourne sand people': trueskill.Rating(mu=25.000, sigma=8.333),
#  'the swanbourne identity': trueskill.Rating(mu=25.000, sigma=8.333),
#  'u.s.s.r': trueskill.Rating(mu=25.000, sigma=8.333),
#  'ussr': trueskill.Rating(mu=8.689, sigma=8.333),
#  'vic park vanguards': trueskill.Rating(mu=25.000, sigma=8.333),
#  'wembley blue light discos': trueskill.Rating(mu=24.085, sigma=8.333),
#  'wembley food caughts': trueskill.Rating(mu=29.115, sigma=8.333),
#  'wembley food courts': trueskill.Rating(mu=26.806, sigma=8.333),
#  'west coast spastic eagles': trueskill.Rating(mu=17.718, sigma=8.333),
#  'west leederville wobbegongs': trueskill.Rating(mu=26.873, sigma=8.333),
#  'west stirling banjo breakers': trueskill.Rating(mu=36.594, sigma=8.333),
#  "westeros perth r'hllors": trueskill.Rating(mu=25.000, sigma=8.333),
#  'whitfords city turbo tuggers': trueskill.Rating(mu=25.000, sigma=8.333),
#  'whitfords city wristies': trueskill.Rating(mu=22.730, sigma=8.333),
#  'whorebin grovers': trueskill.Rating(mu=18.018, sigma=8.333),
#  'willo wonkas': trueskill.Rating(mu=27.744, sigma=8.333),
#  'wilson castaways': trueskill.Rating(mu=18.217, sigma=8.333),
#  "yokine drugs n' crime": trueskill.Rating(mu=25.000, sigma=8.333),
#  'yokine reservoir dogs': trueskill.Rating(mu=27.570, sigma=8.333),
#  'you used to como on my cell phone': trueskill.Rating(mu=25.000, sigma=8.333)}

# %%
# Update the ratings
# Go through each row in winloss results, update the ratings of both teams
# Rating(TeamWhoWon, TeamWhoLost, DidTheGameDraw)
for i in range(0,len(winloss)):
    mergedratings[winloss['Winteam'][i]],mergedratings[winloss['Lossteam'][i]] = rate_1vs1(mergedratings[winloss['Winteam'][i]],
                                                                                      mergedratings[winloss['Lossteam'][i]],
                                                                                      drawn=winloss['IsDraw'][i])

mergedratings
# Out:
# {'50 shades of graylands': trueskill.Rating(mu=24.642, sigma=2.719),
#  'applecross dressers': trueskill.Rating(mu=14.521, sigma=8.333),
#  'attafail whales': trueskill.Rating(mu=10.840, sigma=8.333),
#  'balcatta bandits': trueskill.Rating(mu=48.901, sigma=3.171),
#  'balingup bruisers': trueskill.Rating(mu=19.744, sigma=2.851),
#  'bayslaughter house 5': trueskill.Rating(mu=29.051, sigma=2.662),
#  'bayswater barracudas': trueskill.Rating(mu=21.685, sigma=2.649),
#  'bayswater croquet club': trueskill.Rating(mu=32.665, sigma=3.128),
#  'bedford rave lords': trueskill.Rating(mu=25.848, sigma=3.139),
#  'bicton banter lords': trueskill.Rating(mu=36.958, sigma=2.882),
#  'bicton bath salts': trueskill.Rating(mu=18.808, sigma=8.333),
#  "bicton four 'n twenty": trueskill.Rating(mu=26.523, sigma=2.675),
#  "bicton four'n twenty": trueskill.Rating(mu=20.953, sigma=8.333),
#  'black wall reach arounds': trueskill.Rating(mu=30.801, sigma=2.861),
#  'booragoonbags': trueskill.Rating(mu=18.411, sigma=8.333),
#  'booragoonbagz': trueskill.Rating(mu=15.318, sigma=3.068),
#  'brentwood bushchooks': trueskill.Rating(mu=40.001, sigma=8.333),
#  'bull creek buttchuggers': trueskill.Rating(mu=19.712, sigma=8.333),
#  'burswood 6100s': trueskill.Rating(mu=24.426, sigma=3.080),
#  'canning bridge trolls': trueskill.Rating(mu=32.919, sigma=2.905),
#  'chick park': trueskill.Rating(mu=20.301, sigma=8.333),
#  'churchlands hellraisers': trueskill.Rating(mu=39.244, sigma=3.340),
#  'city beach groins': trueskill.Rating(mu=25.922, sigma=8.333),
#  'city beach kooks': trueskill.Rating(mu=24.569, sigma=3.151),
#  'claremont cereal killahs': trueskill.Rating(mu=30.314, sigma=2.752),
#  'como at me bro': trueskill.Rating(mu=22.294, sigma=2.749),
#  'como mo co': trueskill.Rating(mu=45.129, sigma=2.942),
#  'cottesloe clam hunters': trueskill.Rating(mu=32.010, sigma=8.333),
#  'cottesloe cowards': trueskill.Rating(mu=29.174, sigma=8.333),
#  "cottesloe's hottest hoes": trueskill.Rating(mu=17.175, sigma=8.333),
#  'cotteslowbros': trueskill.Rating(mu=24.826, sigma=8.333),
#  'creepy crawleys': trueskill.Rating(mu=23.973, sigma=8.333),
#  'daglish dhe moisties': trueskill.Rating(mu=35.961, sigma=8.333),
#  'dalkeith dalqueefs': trueskill.Rating(mu=27.346, sigma=3.035),
#  "dalkeith urban's": trueskill.Rating(mu=15.051, sigma=2.671),
#  'dianella demons': trueskill.Rating(mu=24.681, sigma=2.862),
#  'dog swamp swamp dogs': trueskill.Rating(mu=29.404, sigma=3.188),
#  'doubleview double yewws': trueskill.Rating(mu=25.059, sigma=3.092),
#  'east freo bae blades': trueskill.Rating(mu=10.980, sigma=3.617),
#  'floreat flamingos': trueskill.Rating(mu=20.390, sigma=8.333),
#  'fremantle cappuccino strippers': trueskill.Rating(mu=21.304, sigma=8.333),
#  'fremantle metropolis double blacks': trueskill.Rating(mu=14.722, sigma=3.026),
#  'freo dirty dog beachers': trueskill.Rating(mu=20.573, sigma=2.901),
#  'freo fussy puckers': trueskill.Rating(mu=24.970, sigma=8.333),
#  'get bentley': trueskill.Rating(mu=19.294, sigma=2.867),
#  'gmla angels': trueskill.Rating(mu=33.898, sigma=3.066),
#  'gmla guardians': trueskill.Rating(mu=35.413, sigma=3.623),
#  'gmla jurassic pucks': trueskill.Rating(mu=19.049, sigma=3.090),
#  'gravel road grindrs': trueskill.Rating(mu=18.198, sigma=8.333),
#  'greenmount doom': trueskill.Rating(mu=37.797, sigma=2.654),
#  'heathcote hangers': trueskill.Rating(mu=25.060, sigma=3.301),
#  'high gates': trueskill.Rating(mu=24.812, sigma=2.519),
#  'highgate hommus-sexuals': trueskill.Rating(mu=30.703, sigma=8.333),
#  'hillarys humpbacks': trueskill.Rating(mu=14.478, sigma=3.316),
#  'how much wood would a parkwood park if a parkwood could park wood': trueskill.Rating(mu=30.026, sigma=2.791),
#  'hungry spot heroes': trueskill.Rating(mu=30.938, sigma=2.955),
#  'hyde park hacks': trueskill.Rating(mu=26.354, sigma=2.894),
#  'hydepark hacks': trueskill.Rating(mu=26.497, sigma=8.333),
#  'inglewood coldcuts': trueskill.Rating(mu=21.562, sigma=3.002),
#  'innaloo pinguz': trueskill.Rating(mu=20.003, sigma=8.333),
#  'innaloominati': trueskill.Rating(mu=28.499, sigma=3.199),
#  'jason alexander heights': trueskill.Rating(mu=16.856, sigma=2.894),
#  'k-town cooks': trueskill.Rating(mu=33.902, sigma=3.150),
#  'kalamunda hillbillies': trueskill.Rating(mu=18.753, sigma=3.085),
#  'karrakatta grim jobs': trueskill.Rating(mu=37.066, sigma=3.289),
#  'karrinyup bandits': trueskill.Rating(mu=29.301, sigma=8.333),
#  'kensington kermits': trueskill.Rating(mu=28.996, sigma=2.930),
#  'labia menora explorers': trueskill.Rating(mu=32.149, sigma=3.144),
#  'lake mongrels': trueskill.Rating(mu=25.846, sigma=2.990),
#  'leederphiles rolferhockey': trueskill.Rating(mu=23.550, sigma=8.333),
#  'leeming chin': trueskill.Rating(mu=26.271, sigma=2.711),
#  'manning manchilds': trueskill.Rating(mu=20.903, sigma=3.094),
#  'marmion mighty drunks': trueskill.Rating(mu=19.339, sigma=3.020),
#  'maylands muthapuckas': trueskill.Rating(mu=36.822, sigma=3.145),
#  'melville massiv': trueskill.Rating(mu=36.184, sigma=8.333),
#  'mindarie molotovs': trueskill.Rating(mu=42.856, sigma=3.204),
#  'morley puck troopers': trueskill.Rating(mu=39.230, sigma=3.057),
#  'morning brentwood': trueskill.Rating(mu=36.272, sigma=3.163),
#  'mosman mooseknuckles': trueskill.Rating(mu=33.901, sigma=2.961),
#  'mosman park milkmen': trueskill.Rating(mu=25.650, sigma=8.333),
#  'mosmanonymous': trueskill.Rating(mu=9.797, sigma=8.333),
#  "mount hawt'n'horny": trueskill.Rating(mu=9.203, sigma=3.044),
#  'mount lawless': trueskill.Rating(mu=41.362, sigma=4.071),
#  'mt lawley chai lattes': trueskill.Rating(mu=17.498, sigma=8.333),
#  'mt pleasant mounties': trueskill.Rating(mu=30.027, sigma=3.203),
#  'mullaloozers': trueskill.Rating(mu=33.381, sigma=3.129),
#  'murray street tramps': trueskill.Rating(mu=20.872, sigma=3.123),
#  'm\xf6rley cr\xfce': trueskill.Rating(mu=28.039, sigma=2.942),
#  'nedlands flanders': trueskill.Rating(mu=19.149, sigma=3.142),
#  'nedlands yung puccbois': trueskill.Rating(mu=23.282, sigma=8.333),
#  'north beach bearded clams': trueskill.Rating(mu=19.809, sigma=2.574),
#  'north perth bald beavers': trueskill.Rating(mu=22.171, sigma=2.962),
#  "northbridge mdm8's": trueskill.Rating(mu=31.314, sigma=2.984),
#  'ocean beef': trueskill.Rating(mu=24.634, sigma=3.134),
#  'palmyra puck patrol': trueskill.Rating(mu=29.773, sigma=3.012),
#  'parkwood benders': trueskill.Rating(mu=25.659, sigma=8.333),
#  'patrick bateman': trueskill.Rating(mu=46.430, sigma=3.027),
#  'perth city puck pirates': trueskill.Rating(mu=19.359, sigma=2.664),
#  'perth glory holes': trueskill.Rating(mu=25.577, sigma=3.341),
#  'perth glory holez': trueskill.Rating(mu=18.450, sigma=8.333),
#  'perth glory-holerz': trueskill.Rating(mu=18.270, sigma=8.333),
#  'perth on heat': trueskill.Rating(mu=24.034, sigma=8.333),
#  'riverton regretzkys': trueskill.Rating(mu=36.277, sigma=2.923),
#  'rocko rodents': trueskill.Rating(mu=5.619, sigma=3.532),
#  "rocko's modern rollers": trueskill.Rating(mu=17.276, sigma=2.907),
#  'roleystone henges': trueskill.Rating(mu=19.906, sigma=2.940),
#  'rollerburger leedervillains': trueskill.Rating(mu=31.475, sigma=3.093),
#  'rosemount rinsers': trueskill.Rating(mu=30.518, sigma=8.333),
#  'rottnest holy quokkamoles': trueskill.Rating(mu=25.596, sigma=2.832),
#  'salter point pint sucklers': trueskill.Rating(mu=26.858, sigma=3.231),
#  'salter point shooters': trueskill.Rating(mu=23.893, sigma=8.333),
#  'scarbara kadabra': trueskill.Rating(mu=24.462, sigma=2.839),
#  'scarborough scar bros': trueskill.Rating(mu=25.453, sigma=3.163),
#  'scarbra streisands': trueskill.Rating(mu=28.807, sigma=8.333),
#  'shannon nollamaras': trueskill.Rating(mu=17.886, sigma=2.681),
#  'shenton park speed dealers': trueskill.Rating(mu=19.682, sigma=8.333),
#  'south perth major blazers': trueskill.Rating(mu=19.111, sigma=2.775),
#  'south perth puckaneers': trueskill.Rating(mu=18.991, sigma=8.333),
#  "south perth sam's green eggs and ham": trueskill.Rating(mu=11.983, sigma=3.113),
#  'south perth shakas': trueskill.Rating(mu=22.875, sigma=3.260),
#  'st james addictions': trueskill.Rating(mu=19.451, sigma=2.716),
#  'stirling archers': trueskill.Rating(mu=17.269, sigma=3.031),
#  "stirling from the bottom now we're here": trueskill.Rating(mu=17.295, sigma=2.940),
#  'stoneville sloths': trueskill.Rating(mu=24.655, sigma=2.769),
#  'subiaco silkworms': trueskill.Rating(mu=23.869, sigma=2.921),
#  'swan view draught': trueskill.Rating(mu=38.998, sigma=2.900),
#  'swan view sharks': trueskill.Rating(mu=22.457, sigma=8.333),
#  'swanbourne nudists': trueskill.Rating(mu=22.901, sigma=2.989),
#  'swanbourne sand people': trueskill.Rating(mu=20.891, sigma=2.747),
#  'the swanbourne identity': trueskill.Rating(mu=42.134, sigma=3.025),
#  'u.s.s.r': trueskill.Rating(mu=16.070, sigma=3.022),
#  'ussr': trueskill.Rating(mu=8.689, sigma=8.333),
#  'vic park vanguards': trueskill.Rating(mu=17.853, sigma=5.951),
#  'wembley blue light discos': trueskill.Rating(mu=31.040, sigma=3.003),
#  'wembley food caughts': trueskill.Rating(mu=29.115, sigma=8.333),
#  'wembley food courts': trueskill.Rating(mu=31.966, sigma=3.352),
#  'west coast spastic eagles': trueskill.Rating(mu=17.718, sigma=8.333),
#  'west leederville wobbegongs': trueskill.Rating(mu=26.873, sigma=8.333),
#  'west stirling banjo breakers': trueskill.Rating(mu=28.742, sigma=3.252),
#  "westeros perth r'hllors": trueskill.Rating(mu=10.087, sigma=3.376),
#  'whitfords city turbo tuggers': trueskill.Rating(mu=21.012, sigma=3.121),
#  'whitfords city wristies': trueskill.Rating(mu=22.730, sigma=8.333),
#  'whorebin grovers': trueskill.Rating(mu=18.018, sigma=8.333),
#  'willo wonkas': trueskill.Rating(mu=27.744, sigma=8.333),
#  'wilson castaways': trueskill.Rating(mu=24.147, sigma=2.605),
#  "yokine drugs n' crime": trueskill.Rating(mu=15.198, sigma=3.010),
#  'yokine reservoir dogs': trueskill.Rating(mu=27.565, sigma=2.956),
#  'you used to como on my cell phone': trueskill.Rating(mu=21.995, sigma=2.495)}

# %%
# Convert the new ratings from a dict to a dataframe
# Make sure to extract mu and sigma values for each team for ease of importing the rating objects
# Storing as a csv will turn the rating objects back in to text

skill_df = DataFrame(mergedratings.items(),columns=['Team','Rating'])

skill_df['mu'] = None
skill_df['sigma'] = None
for i in range(0,len(skill_df)):
    skill_df['mu'][i]=skill_df['Rating'][i].mu
    skill_df['sigma'][i]=skill_df['Rating'][i].sigma
    #skill_df['Team'][i] = skill_df['Team'][i].lower()

# Write the newskill results to wherever was specified
skill_df.to_csv(newskill_csv)
skill_df.head()
# Out:
#                         Team                                    Rating  \
# 0        mosman park milkmen  trueskill.Rating(mu=25.650, sigma=8.333)
# 1  south perth major blazers  trueskill.Rating(mu=19.111, sigma=2.775)
# 2        gmla jurassic pucks  trueskill.Rating(mu=19.049, sigma=3.090)
# 3            creepy crawleys  trueskill.Rating(mu=23.973, sigma=8.333)
# 4       mt pleasant mounties  trueskill.Rating(mu=30.027, sigma=3.203)
#
#         mu    sigma
# 0  25.6503  8.33333
# 1   19.111  2.77543
# 2  19.0489  3.09041
# 3  23.9728  8.33333
# 4  30.0267  3.20345

# %%
# Use this to re init the ratings from text back in to rating objects
# Doesn't necessarily need to run

skill_df = pd.read_csv(newskill_csv)
for i in range(0,len(skill_df)):
               skill_df['Rating'][i] = Rating(mu=skill_df['mu'][i],
                                                sigma=skill_df['sigma'][i])
skill_df.head()
# Out:
# C:\Anaconda2\lib\site-packages\ipykernel\__main__.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#    Unnamed: 0                       Team  \
# 0           0        mosman park milkmen
# 1           1  south perth major blazers
# 2           2        gmla jurassic pucks
# 3           3            creepy crawleys
# 4           4       mt pleasant mounties
#
#                                      Rating         mu     sigma
# 0  trueskill.Rating(mu=25.650, sigma=8.333)  25.650328  8.333333
# 1  trueskill.Rating(mu=19.111, sigma=2.775)  19.111039  2.775426
# 2  trueskill.Rating(mu=19.049, sigma=3.090)  19.048920  3.090409
# 3  trueskill.Rating(mu=23.973, sigma=8.333)  23.972845  8.333333
# 4  trueskill.Rating(mu=30.027, sigma=3.203)  30.026670  3.203453

# %%
import winsound
winsound.Beep(2000,500)
